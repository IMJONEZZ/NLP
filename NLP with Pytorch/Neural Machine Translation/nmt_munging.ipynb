# %%
from argparse import Namespace
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
import numpy as np
import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\chris\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
args = Namespace(
    source_data_path="../data/nmt/eng-rus.txt",
    output_data_path="../data/nmt/eng_rus.csv",
    perc_train=0.7,
    perc_val=0.15,
    perc_test=0.15,
    seed=1337
)

assert args.perc_test > 0 and (args.perc_test + args.perc_val + args.perc_train == 1.0)

# %%
with open(args.source_data_path, encoding='utf-8') as fp:
    lines = fp.readlines()
    
lines = [line.replace("\n", "").lower().split("\t") for line in lines]

# %%
data = []
for english_sentence, russian_sentence, _ in lines:
    data.append({"english_tokens": word_tokenize(english_sentence, language="english"),
                 "russian_tokens": word_tokenize(russian_sentence, language="russian")})

# %%
filter_phrases = (
    ("i", "am"), ("i", "'m"), 
    ("he", "is"), ("he", "'s"),
    ("she", "is"), ("she", "'s"),
    ("you", "are"), ("you", "'re"),
    ("we", "are"), ("we", "'re"),
    ("they", "are"), ("they", "'re")
)

# %%
filter = False

if filter:
    data_subset = {phrase: [] for phrase in filter_phrases}
    for datum in data:
        key = tuple(datum['english_tokens'][:2])
        if key in data_subset:
            data_subset[key].append(datum)
else:
    data_subset = {}
    for datum in data:
        key = tuple(datum['english_tokens'][:2])
        if key in data_subset:
            data_subset[key].append(datum)
        else:
            data_subset[key] = [datum]

# %%
counts = {k: len(v) for k,v in data_subset.items()}
counts, sum(counts.values())
# Out:
# tom', 'ran'): 116,
#   ('tom', 'won'): 44,
#   ('wake', 'up'): 16,
#   ('wash', 'up'): 1,
#   ('we', 'care'): 2,
#   ('we', 'know'): 309,
#   ('we', 'lost'): 33,
#   ('who', 'ate'): 13,
#   ('who', 'ran'): 3,
#   ('who', 'won'): 8,
#   ('why', 'not'): 42,
#   ('you', 'run'): 4,
#   ('you', 'won'): 10,
#   ('am', 'i'): 203,
#   ('ask', 'them'): 13,
#   ('back', 'off'): 11,
#   ('be', 'a'): 9,
#   ('be', 'brave'): 2,
#   ('be', 'brief'): 4,
#   ('be', 'quiet'): 17,
#   ('beats', 'me'): 1,
#   ('buzz', 'off'): 1,
#   ('bye', ','): 1,
#   ('call', 'tom'): 26,
#   ('catch', 'me'): 5,
#   ('cheer', 'up'): 4,
#   ('cool', 'off'): 1,
#   ('cuff', 'him'): 2,
#   ('do', "n't"): 5882,
#   ('drive', 'on'): 2,
#   ('find', 'tom'): 15,
#   ('fix', 'this'): 4,
#   ('get', 'away'): 13,
#   ('get', 'busy'): 4,
#   ('get', 'down'): 22,
#   ('get', 'lost'): 18,
#   ('get', 'real'): 2,
#   ('go', 'ahead'): 26,
#   ('good', 'job'): 2,
#   ('grab', 'tom'): 2,
#   ('grab', 'him'): 3,
#   ('have', 'fun'): 8,
#   ('he', 'spoke'): 16,
#   ('he', 'tried'): 59,
#   ('he', "'s"): 950,
#   ('help', 'tom'): 12,
#   ('how', 'cute'): 1,
#   ('how', 'deep'): 15,
#   ('how', 'rude'): 2,
#   ('humor', 'me'): 2,
#   ('hurry', 'up'): 78,
#   ('i', 'agreed'): 30,
#   ('i', 'am'): 1214,
#   ('i', 'ate'): 118,
#   ('i', 'burped'): 1,
#   ('i', 'can'): 1014,
#   ('i', 'danced'): 4,
#   ('i', 'did'): 5197,
#   ('i', 'failed'): 20,
#   ('i', 'gasped'): 1,
#   ('i', 'get'): 126,
#   ('i', 'goofed'): 4,
#   ('i', 'got'): 608,
#   ('i', 'helped'): 77,
#   ('i', 'jumped'): 7,
#   ('i', 'looked'): 101,
#   ('i', 'moaned'): 1,
#   ('i', 'nodded'): 10,
#   ('i', 'obeyed'): 4,
#   ('i', 'paused'): 2,
#   ('i', 'phoned'): 6,
#   ('i', 'prayed'): 5,
#   ('i', 'refuse'): 43,
#   ('i', 'resign'): 1,
#   ('i', 'saw'): 829,
#   ('i', 'shaved'): 3,
#   ('i', 'sighed'): 1,
#   ('i', 'smiled'): 6,
#   ('i', 'stayed'): 75,
#   ('i', 'talked'): 72,
#   ('i', 'use'): 26,
#   ('i', 'waited'): 61,
#   ('i', 'winked'): 3,
#   ('i', 'yawned'): 2,
#   ('i', "'d"): 2130,
#   ('i', "'ve"): 4920,
#   ('it', 'helps'): 1,
#   ('it', 'hurts'): 8,
#   ('it', 'works'): 15,
#   ('keep', 'out'): 5,
#   ('kill', 'tom'): 2,
#   ('kiss', 'tom'): 4,
#   ('leave', 'it'): 35,
#   ('leave', 'me'): 23,
#   ('leave', 'us'): 11,
#   ('let', "'s"): 2815,
#   ('look', 'out'): 19,
#   ('marry', 'me'): 6,
#   ('may', 'i'): 587,
#   ('run', 'away'): 3,
#   ('save', 'tom'): 2,
#   ('she', 'came'): 49,
#   ('she', 'died'): 16,
#   ('she', 'left'): 41,
#   ('she', 'lied'): 1,
#   ('she', 'runs'): 4,
#   ('sit', 'down'): 50,
#   ('sit', 'here'): 7,
#   ('speak', 'up'): 2,
#   ('stand', 'by'): 3,
#   ('stand', 'up'): 29,
#   ('stay', 'put'): 1,
#   ('stop', 'tom'): 2,
#   ('take', 'tom'): 16,
#   ('taste', 'it'): 4,
#   ('tell', 'tom'): 769,
#   ('terrific', '!'): 4,
#   ('they', 'won'): 8,
#   ('tom', 'came'): 310,
#   ('tom', 'died'): 262,
#   ('tom', 'fell'): 160,
#   ('tom', 'knew'): 540,
#   ('tom', 'left'): 326,
#   ('tom', 'lied'): 32,
#   ('tom', 'lies'): 7,
#   ('tom', 'lost'): 178,
#   ('tom', 'paid'): 59,
#   ('tom', 'quit'): 17,
#   ('tom', 'sang'): 35,
#   ('tom', 'swam'): 9,
#   ('tom', 'went'): 429,
#   ('tom', 'wept'): 1,
#   ('too', 'late'): 1,
#   ('touch', 'it'): 8,
#   ('trust', 'me'): 9,
#   ('try', 'hard'): 1,
#   ('try', 'some'): 6,
#   ('try', 'this'): 22,
#   ('use', 'this'): 1,
#   ('warn', 'tom'): 6,
#   ('we', 'agree'): 9,
#   ('we', 'cried'): 2,
#   ('we', 'moved'): 8,
#   ('we', 'tried'): 48,
#   ('we', "'ll"): 1186,
#   ('we', "'re"): 2446,
#   ('what', 'for'): 3,
#   ('what', 'fun'): 2,
#   ('who', 'came'): 6,
#   ('who', 'died'): 4,
#   ('who', 'fell'): 1,
#   ('who', 'lost'): 1,
#   ('who', 'paid'): 9,
#   ('who', 'quit'): 2,
#   ('who', 'swam'): 1,
#   ('write', 'me'): 12,
#   ('you', 'lost'): 11,
#   ('after', 'you'): 6,
#   ('aim', '.'): 2,
#   ('answer', 'me'): 9,
#   ('be', 'honest'): 5,
#   ('birds', 'fly'): 4,
#   ('bless', 'you'): 1,
#   ('call', 'home'): 2,
#   ('calm', 'down'): 12,
#   ('can', 'i'): 893,
#   ('can', 'we'): 254,
#   ('catch', 'tom'): 6,
#   ('catch', 'him'): 3,
#   ('chill', 'out'): 1,
#   ('choose', 'me'): 1,
#   ('clear', 'out'): 1,
#   ('come', 'back'): 51,
#   ('come', 'here'): 35,
#   ('come', 'home'): 15,
#   ('come', 'over'): 20,
#   ('come', 'soon'): 4,
#   ('cool', 'down'): 2,
#   ('did', 'i'): 142,
#   ('dogs', 'bark'): 2,
#   ('excuse', 'me'): 126,
#   ('fantastic', '!'): 1,
#   ('find', 'them'): 2,
#   ('follow', 'me'): 8,
#   ('follow', 'us'): 6,
#   ('forget', 'it'): 6,
#   ('forget', 'me'): 2,
#   ('get', 'a'): 22,
#   ('get', 'ready'): 8,
#   ('go', 'get'): 38,
#   ('go', 'inside'): 4,
#   ('go', 'slower'): 2,
#   ('go', 'to'): 52,
#   ('goodnight', '.'): 1,
#   ('grab', 'that'): 4,
#   ('grab', 'this'): 5,
#   ('hands', 'off'): 2,
#   ('have', 'some'): 22,
#   ('he', 'is'): 1330,
#   ('he', 'shaved'): 3,
#   ('he', 'smiled'): 5,
#   ('head', 'east'): 2,
#   ('head', 'west'): 2,
#   ('here', 'i'): 3,
#   ('here', "'s"): 211,
#   ('hold', 'fire'): 1,
#   ('hold', 'this'): 4,
#   ('how', 'awful'): 2,
#   ('how', 'funny'): 1,
#   ('how', 'weird'): 1,
#   ('how', "'s"): 140,
#   ('i', 'approve'): 4,
#   ('i', 'beg'): 17,
#   ('i', 'blinked'): 2,
#   ('i', 'cheated'): 4,
#   ('i', 'cheered'): 2,
#   ('i', 'coughed'): 2,
#   ('i', 'crashed'): 2,
#   ('i', 'cringed'): 1,
#   ('i', 'escaped'): 6,
#   ('i', 'fainted'): 2,
#   ('i', 'fear'): 9,
#   ('i', 'frowned'): 2,
#   ('i', 'gave'): 200,
#   ('i', 'giggled'): 2,
#   ('i', 'give'): 15,
#   ('i', 'gloated'): 2,
#   ('i', 'grinned'): 2,
#   ('i', 'groaned'): 5,
#   ('i', 'grunted'): 2,
#   ('i', 'hate'): 402,
#   ('i', 'have'): 4585,
#   ('i', 'hit'): 15,
#   ('i', 'hope'): 1715,
#   ('i', 'knew'): 1562,
#   ('i', 'laughed'): 23,
#   ('i', 'like'): 1230,
#   ('i', 'love'): 547,
#   ('i', 'made'): 241,
#   ('i', 'may'): 80,
#   ('i', 'mean'): 6,
#   ('i', 'met'): 211,
#   ('i', 'miss'): 108,
#   ('i', 'must'): 357,
#   ('i', 'need'): 1441,
#   ('i', 'noticed'): 41,
#   ('i', 'prepaid'): 4,
#   ('i', 'promise'): 199,
#   ('i', 'relaxed'): 3,
#   ('i', 'retired'): 7,
#   ('i', 'said'): 233,
#   ('i', 'slipped'): 12,
#   ('i', 'sneezed'): 2,
#   ('i', 'stopped'): 34,
#   ('i', 'studied'): 32,
#   ('i', 'sweated'): 2,
#   ('i', 'tripped'): 4,
#   ('i', 'want'): 4156,
#   ('i', 'was'): 3844,
#   ('i', 'will'): 561,
#   ('i', 'woke'): 56,
#   ('ignore', 'it'): 5,
#   ('is', 'tom'): 598,
#   ('is', 'he'): 46,
#   ('is', 'it'): 666,
#   ('it', 'burned'): 3,
#   ('it', 'failed'): 3,
#   ('it', 'rained'): 71,
#   ('it', 'snowed'): 20,
#   ('it', 'stinks'): 3,
#   ('it', 'worked'): 8,
#   ('just', 'swim'): 1,
#   ('keep', 'away'): 14,
#   ('keep', 'back'): 1,
#   ('keep', 'calm'): 1,
#   ('keep', 'cool'): 2,
#   ('keep', 'down'): 1,
#   ('keep', 'them'): 4,
#   ('keep', 'this'): 7,
#   ('keep', 'warm'): 6,
#   ('kill', 'them'): 2,
#   ('leave', 'tom'): 10,
#   ('leave', 'now'): 1,
#   ('let', 'it'): 2,
#   ('let', 'me'): 847,
#   ('let', 'us'): 57,
#   ('lie', 'still'): 4,
#   ('listen', 'up'): 2,
#   ('look', 'away'): 2,
#   ('look', 'back'): 6,
#   ('look', 'here'): 2,
#   ('loosen', 'it'): 1,
#   ('loosen', 'up'): 1,
#   ('move', 'over'): 2,
#   ('nice', 'shot'): 1,
#   ('of', 'course'): 102,
#   ('oh', 'please'): 1,
#   ('open', 'fire'): 3,
#   ('pardon', 'me'): 16,
#   ('pipe', 'down'): 1,
#   ('please', 'go'): 52,
#   ('put', 'it'): 179,
#   ('read', 'this'): 19,
#   ('say', '``'): 2,
#   ('say', 'hello'): 15,
#   ('search', 'me'): 1,
#   ('see', 'above'): 1,
#   ('see', 'below'): 1,
#   ('seize', 'him'): 2,
#   ('seriously', '?'): 2,
#   ('she', 'cried'): 7,
#   ('she', 'tried'): 39,
#   ('she', 'walks'): 1,
#   ('she', "'s"): 442,
#   ('sign', 'here'): 9,
#   ('sign', 'this'): 2,
#   ('sit', 'still'): 2,
#   ('sit', 'there'): 2,
#   ('sit', 'tight'): 2,
#   ('slow', 'down'): 10,
#   ('start', 'now'): 4,
#   ('stay', 'away'): 34,
#   ('stay', 'back'): 1,
#   ('stay', 'calm'): 2,
#   ('stay', 'down'): 3,
#   ('stay', 'here'): 55,
#   ('stay', 'home'): 7,
#   ('step', 'back'): 2,
#   ('stop', 'here'): 4,
#   ('stop', 'that'): 17,
#   ('stop', 'them'): 2,
#   ('take', 'care'): 26,
#   ('take', 'mine'): 20,
#   ('take', 'over'): 2,
#   ('take', 'this'): 68,
#   ('thank', 'you'): 413,
#   ('that', "'s"): 2966,
#   ('then', 'what'): 1,
#   ('they', 'fell'): 3,
#   ('they', 'left'): 27,
#   ('they', 'lied'): 9,
#   ('they', 'lost'): 11,
#   ('they', 'swam'): 4,
#   ('time', "'s"): 6,
#   ('tom', 'began'): 122,
#   ('tom', 'bowed'): 5,
#   ('tom', 'cared'): 2,
#   ('tom', 'cares'): 6,
#   ('tom', 'cooks'): 13,
#   ('tom', 'cried'): 27,
#   ('tom', 'dozed'): 6,
#   ('tom', 'drove'): 48,
#   ('tom', 'fired'): 13,
#   ('tom', 'is'): 11810,
#   ('tom', 'knelt'): 5,
#   ('tom', 'knits'): 1,
#   ('tom', 'knows'): 807,
#   ('tom', 'moved'): 70,
#   ('tom', 'reads'): 30,
#   ('tom', 'rocks'): 1,
#   ('tom', 'slept'): 78,
#   ('tom', 'spoke'): 66,
#   ('tom', 'stood'): 58,
#   ('tom', 'swims'): 30,
#   ('tom', 'swore'): 20,
#   ('tom', 'tried'): 416,
#   ('tom', 'tries'): 4,
#   ('tom', 'voted'): 13,
#   ('tom', 'walks'): 30,
#   ('tom', 'waved'): 19,
#   ('tom', 'works'): 154,
#   ('tom', "'ll"): 30,
#   ('tom', "'s"): 1816,
#   ('trust', 'tom'): 3,
#   ('try', 'again'): 2,
#   ('turn', 'left'): 14,
#   ('unlock', 'it'): 4,
#   ('wait', 'here'): 33,
#   ('watch', 'tom'): 4,
#   ('watch', 'out'): 11,
#   ('way', 'to'): 3,
#   ('we', 'agreed'): 17,
#   ('we', 'can'): 263,
#   ('we', 'danced'): 3,
#   ('we', 'did'): 340,
#   ('we', 'failed'): 2,
#   ('we', 'forgot'): 6,
#   ('we', 'prayed'): 3,
#   ('we', 'saw'): 80,
#   ('we', 'smiled'): 2,
#   ('we', 'talked'): 67,
#   ('we', 'waited'): 35,
#   ('we', 'yawned'): 1,
#   ('we', "'ve"): 854,
#   ('well', 'done'): 4,
#   ('what', "'s"): 1546,
#   ('who', 'cares'): 24,
#   ('who', 'drove'): 2,
#   ('who', 'is'): 140,
#   ('who', 'knows'): 40,
#   ('who', 'spoke'): 2,
#   ('who', 'stood'): 1,
#   ('who', "'ll"): 68,
#   ('who', "'s"): 449,
#   ('wonderful', '!'): 2,
#   ('write', 'tom'): 4,
#   ('you', 'drive'): 7,
#   ('you', 'idiot'): 2,
#   ('you', 'start'): 2,
#   ('you', 'stink'): 2,
#   ('you', 'tried'): 8,
#   ('you', "'re"): 4951,
#   ('aim', 'higher'): 2,
#   ('all', 'aboard'): 3,
#   ('answer', 'tom'): 4,
#   ('are', 'you'): 4190,
#   ('ask', 'anyone'): 2,
#   ('ask', 'around'): 6,
#   ('be', 'careful'): 130,
#   ('be', 'content'): 3,
#   ('be', 'on'): 4,
#   ('be', 'patient'): 6,
#   ('be', 'serious'): 8,
#   ('birds', 'sing'): 3,
#   ('bottoms', 'up'): 1,
#   ('bring', 'food'): 2,
#   ('bring', 'help'): 2,
#   ('bring', 'wine'): 2,
#   ('carry', 'this'): 3,
#   ('catch', 'this'): 2,
#   ('check', 'that'): 2,
#   ('check', 'this'): 11,
#   ('choose', 'one'): 18,
#   ('come', 'again'): 7,
#   ('come', 'alone'): 1,
#   ('come', 'early'): 2,
#   ('come', 'quick'): 3,
#   ('come', 'to'): 34,
#   ('cut', 'it'): 48,
#   ('definitely', '!'): 3,
#   ('destroy', 'it'): 3,
#   ('did', 'tom'): 815,
#   ('did', 'we'): 14,
#   ('dig', 'faster'): 4,
#   ('do', 'i'): 198,
#   ('do', 'come'): 7,
#   ('do', 'men'): 2,
#   ('do', 'you'): 9276,
#   ('drink', 'this'): 5,
#   ('duty', 'calls'): 1,
#   ('eat', 'slowly'): 3,
#   ('enjoy', 'life'): 3,
#   ('examine', 'it'): 4,
#   ('face', 'facts'): 1,
#   ('fill', 'it'): 2,
#   ('find', 'a'): 4,
#   ('follow', 'tom'): 4,
#   ('follow', 'him'): 4,
#   ('forget', 'tom'): 4,
#   ('forget', 'him'): 2,
#   ('forgive', 'me'): 12,
#   ('forgive', 'us'): 2,
#   ('get', 'moving'): 2,
#   ('get', 'off'): 12,
#   ('get', 'to'): 16,
#   ('give', 'it'): 66,
#   ('go', 'outside'): 3,
#   ('go', 'see'): 9,
#   ('god', 'exists'): 2,
#   ('good', 'night'): 6,
#   ('he', 'gave'): 100,
#   ('he', 'got'): 107,
#   ('he', 'hung'): 9,
#   ('he', 'laughed'): 7,
#   ('he', 'made'): 104,
#   ('head', 'north'): 4,
#   ('head', 'south'): 2,
#   ('heat', 'it'): 2,
#   ('hello', ','): 14,
#   ('here', 'he'): 4,
#   ('here', 'it'): 4,
#   ('hold', 'tight'): 2,
#   ('how', 'absurd'): 1,
#   ('how', 'boring'): 2,
#   ('how', 'clever'): 2,
#   ('how', 'is'): 110,
#   ('how', 'lovely'): 1,
#   ('how', 'tragic'): 1,
#   ('how', 'was'): 147,
#   ('hurry', 'back'): 2,
#   ('hurry', 'home'): 1,
#   ('i', 'admit'): 43,
#   ('i', 'broke'): 77,
#   ('i', 'built'): 14,
#   ('i', 'ca'): 2695,
#   ('i', 'canceled'): 13,
#   ('i', 'chew'): 1,
#   ('i', 'chuckled'): 3,
#   ('i', 'disagree'): 19,
#   ('i', 'do'): 11263,
#   ('i', 'doubt'): 216,
#   ('i', 'eat'): 53,
#   ('i', 'envy'): 14,
#   ('i', 'exercise'): 4,
#   ('i', 'feel'): 473,
#   ('i', 'felt'): 200,
#   ('i', 'fixed'): 10,
#   ('i', 'flinched'): 2,
#   ('i', 'found'): 286,
#   ('i', 'guess'): 128,
#   ('i', 'had'): 1105,
#   ('i', 'hear'): 195,
#   ('i', 'help'): 6,
#   ('i', 'just'): 1066,
#   ('i', 'liked'): 86,
#   ('i', 'listened'): 18,
#   ('i', 'panicked'): 2,
#   ('i', 'pity'): 7,
#   ('i', 'promised'): 75,
#   ('i', 'relented'): 2,
#   ('i', 'remember'): 204,
#   ('i', 'resigned'): 1,
#   ('i', 'sat'): 40,
#   ('i', 'screamed'): 4,
#   ('i', 'shivered'): 4,
#   ('i', 'shot'): 9,
#   ('i', 'shrugged'): 2,
#   ('i', 'squinted'): 2,
#   ('i', 'survived'): 1,
#   ('i', 'think'): 5314,
#   ('i', 'threw'): 31,
#   ('i', 'told'): 1419,
#   ('i', 'whistled'): 2,
#   ('i', 'wo'): 864,
#   ('i', 'wrote'): 114,
#   ('ignore', 'tom'): 5,
#   ('ignore', 'him'): 2,
#   ('is', 'that'): 606,
#   ('is', 'this'): 538,
#   ('it', 'happens'): 16,
#   ('it', 'is'): 1049,
#   ('it', 'matters'): 7,
#   ('it', 'was'): 1812,
#   ('it', 'went'): 7,
#   ('it', "'ll"): 321,
#   ('jesus', 'wept'): 1,
#   ('just', 'do'): 85,
#   ('just', 'leave'): 16,
#   ('just', 'relax'): 8,
#   ('keep', 'going'): 12,
#   ('keep', 'notes'): 1,
#   ('keep', 'quiet'): 3,
#   ('lean', 'on'): 2,
#   ('leave', 'town'): 4,
#   ('let', 'tom'): 110,
#   ('let', 'him'): 13,
#   ('lighten', 'up'): 1,
#   ('look', 'again'): 3,
#   ('look', 'ahead'): 1,
#   ('look', 'alive'): 3,
#   ('look', 'at'): 265,
#   ('look', 'there'): 3,
#   ('love', 'hurts'): 2,
#   ('love', 'lasts'): 1,
#   ('mama', 'cried'): 1,
#   ('never', 'mind'): 10,
#   ('no', 'comment'): 2,
#   ('no', 'kidding'): 2,
#   ('no', 'problem'): 6,
#   ('nobody', 'ran'): 1,
#   ('now', 'get'): 15,
#   ('now', 'try'): 11,
#   ('oh', ','): 59,
#   ('once', 'again'): 1,
#   ('pack', 'light'): 2,
#   ('pick', 'it'): 4,
#   ('please', 'eat'): 10,
#   ('please', 'sit'): 19,
#   ('protect', 'me'): 2,
#   ('quiet', 'down'): 4,
#   ('quit', 'lying'): 1,
#   ('replace', 'it'): 4,
#   ('run', 'faster'): 1,
#   ('say', 'cheese'): 1,
#   ('say', 'please'): 1,
#   ('shadow', 'him'): 1,
#   ('she', 'is'): 665,
#   ('shove', 'over'): 1,
#   ('sing', 'along'): 1,
#   ('smell', 'this'): 6,
#   ('stand', 'back'): 2,
#   ('start', 'here'): 4,
#   ('start', 'over'): 8,
#   ('stay', 'alert'): 4,
#   ('stay', 'awake'): 4,
#   ('stay', 'close'): 2,
#   ('stay', 'sharp'): 4,
#   ('stay', 'still'): 4,
#   ('stay', 'there'): 6,
#   ('step', 'aside'): 5,
#   ('stop', 'lying'): 11,
#   ('stop', 'there'): 2,
#   ('study', 'hard'): 4,
#   ('study', 'more'): 2,
#   ('take', 'a'): 110,
#   ('take', 'cover'): 1,
#   ('take', 'notes'): 4,
#   ('take', 'these'): 9,
#   ('talk', 'to'): 38,
#   ('taste', 'this'): 2,
#   ('that', 'a'): 2,
#   ('that', 'hurts'): 2,
#   ('that', 'works'): 2,
#   ('that', "'ll"): 75,
#   ('they', 'agree'): 3,
#   ('they', 'cheat'): 1,
#   ('they', 'slept'): 6,
#   ('they', 'tried'): 15,
#   ('they', 'voted'): 4,
#   ('this', 'is'): 2497,
#   ('this', 'works'): 2,
#   ('time', 'flies'): 2,
#   ('time', 'is'): 21,
#   ('tom', 'agreed'): 41,
#   ('tom', 'agrees'): 11,
#   ('tom', 'bit'): 5,
#   ('tom', 'braked'): 1,
#   ('tom', 'burped'): 1,
#   ('tom', 'called'): 204,
#   ('tom', 'cheats'): 2,
#   ('tom', 'danced'): 6,
#   ('tom', 'dances'): 4,
#   ('tom', 'did'): 3520,
#   ('tom', 'drinks'): 35,
#   ('tom', 'drives'): 33,
#   ('tom', 'failed'): 21,
#   ('tom', 'forgot'): 123,
#   ('tom', 'fought'): 11,
#   ('tom', 'gasped'): 2,
#   ('tom', 'got'): 672,
#   ('tom', 'has'): 4354,
#   ('tom', 'helped'): 161,
#   ('tom', 'hit'): 25,
#   ('tom', 'jumped'): 44,
#   ('tom', 'looked'): 333,
#   ('tom', 'moaned'): 2,
#   ('tom', 'nodded'): 39,
#   ('tom', 'phoned'): 17,
#   ('tom', 'prayed'): 3,
#   ('tom', 'rested'): 3,
#   ('tom', 'saw'): 202,
#   ('tom', 'shaved'): 8,
#   ('tom', 'sighed'): 11,
#   ('tom', 'smiled'): 52,
#   ('tom', 'smokes'): 11,
#   ('tom', 'snored'): 3,
#   ('tom', 'snores'): 5,
#   ('tom', 'stayed'): 93,
#   ('tom', 'talked'): 82,
#   ('tom', 'waited'): 84,
#   ('tom', 'walked'): 116,
#   ('tom', 'was'): 4826,
#   ('tom', 'winked'): 6,
#   ('tom', 'worked'): 78,
#   ('tom', 'yawned'): 1,
#   ('tom', 'yelled'): 11,
#   ('try', 'harder'): 1,
#   ('turn', 'it'): 27,
#   ('turn', 'right'): 12,
#   ('wait', 'a'): 34,
#   ('was', 'he'): 5,
#   ('was', 'it'): 82,
#   ('watch', 'this'): 1,
#   ('we', 'all'): 297,
#   ('we', 'are'): 326,
#   ('we', 'buy'): 3,
#   ('we', 'had'): 290,
#   ('we', 'hope'): 88,
#   ('we', 'laughed'): 7,
#   ('we', 'like'): 35,
#   ('we', 'love'): 34,
#   ('we', 'made'): 46,
#   ('we', 'may'): 37,
#   ('we', 'must'): 291,
#   ('we', 'need'): 586,
#   ('we', 'want'): 239,
#   ('what', 'a'): 233,
#   ('what', 'gives'): 3,
#   ('where', 'am'): 10,
#   ('who', 'are'): 206,
#   ('who', 'did'): 208,
#   ('who', 'has'): 17,
#   ('who', 'hid'): 2,
#   ('who', 'phoned'): 1,
#   ('who', 'saw'): 4,
#   ('who', 'stayed'): 1,
#   ('who', 'was'): 93,
#   ('who', 'yelled'): 1,
#   ('why', 'bother'): 1,
#   ('wood', 'burns'): 4,
#   ('you', 'agreed'): 5,
#   ('you', 'called'): 3,
#   ('you', 'can'): 953,
#   ('you', 'decide'): 1,
#   ('you', 'did'): 424,
#   ('you', 'may'): 351,
#   ('you', 'missed'): 22,
#   ('you', 'owe'): 34,
#   ('you', "'ll"): 861,
#   ('you', "'ve"): 1027,
#   ('all', 'is'): 7,
#   ('anyone', 'home'): 2,
#   ('anyone', 'hurt'): 2,
#   ('are', 'we'): 109,
#   ('ask', 'anybody'): 1,
#   ('ask', 'for'): 3,
#   ('be', 'creative'): 3,
#   ('be', 'discreet'): 1,
#   ('be', 'friendly'): 7,
#   ('be', 'generous'): 2,
#   ('be', 'merciful'): 5,
#   ('be', 'prepared'): 7,
#   ('be', 'punctual'): 6,
#   ('be', 'ruthless'): 6,
#   ('be', 'sensible'): 3,
#   ('be', 'specific'): 2,
#   ('be', 'tolerant'): 4,
#   ('be', 'vigilant'): 3,
#   ('be', 'watchful'): 3,
#   ('be', 'yourself'): 4,
#   ('beer', "'s"): 1,
#   ('behave', 'well'): 2,
#   ('breathe', 'out'): 4,
#   ('bring', 'a'): 17,
#   ('call', 'my'): 12,
#   ('can', 'it'): 14,
#   ('can', 'you'): 1891,
#   ('cancel', 'that'): 2,
#   ('check', 'again'): 2,
#   ('come', 'aboard'): 2,
#   ('come', 'closer'): 6,
#   ('come', 'inside'): 3,
#   ('comfort', 'tom'): 1,
#   ('contact', 'tom'): 2,
#   ('count', 'on'): 2,
#   ('did', 'it'): 22,
#   ('did', 'you'): 3447,
#   ('do', 'as'): 44,
#   ('do', 'your'): 68,
#   ('eat', 'with'): 2,
#   ('finish', 'this'): 1,
#   ('flip', 'a'): 2,
#   ('forgive', 'tom'): 4,
#   ('get', 'changed'): 1,
#   ('get', 'dressed'): 6,
#   ('get', 'in'): 28,
#   ('get', 'serious'): 6,
#   ('get', 'started'): 3,
#   ('go', 'find'): 5,
#   ('go', 'for'): 4,
#   ('go', 'help'): 4,
#   ('go', 'sit'): 5,
#   ('go', 'straight'): 12,
#   ('go', 'tell'): 8,
#   ('go', 'that'): 6,
#   ('go', 'with'): 10,
#   ('have', 'a'): 74,
#   ('have', 'we'): 11,
#   ('he', 'can'): 128,
#   ('he', 'chuckled'): 2,
#   ('he', 'found'): 32,
#   ('he', 'grew'): 8,
#   ('he', 'has'): 569,
#   ('he', 'helps'): 3,
#   ('he', 'loves'): 34,
#   ('he', 'needs'): 21,
#   ('he', 'relented'): 3,
#   ('he', 'squinted'): 1,
#   ('he', 'stood'): 18,
#   ('he', 'was'): 793,
#   ('hear', 'me'): 2,
#   ('hello', 'again'): 2,
#   ('here', 'she'): 3,
#   ('here', 'we'): 10,
#   ('here', ','): 41,
#   ('hey', ','): 147,
#   ('hold', 'my'): 4,
#   ('how', 'are'): 171,
#   ('how', 'curious'): 1,
#   ('how', 'strange'): 2,
#   ('i', 'adore'): 2,
#   ('i', 'also'): 53,
#   ('i', 'apologize'): 32,
#   ('i', 'asked'): 426,
#   ('i', 'assume'): 69,
#   ('i', 'blame'): 15,
#   ('i', 'bought'): 433,
#   ('i', 'buried'): 3,
#   ('i', 'burned'): 24,
#   ('i', 'came'): 248,
#   ('i', 'caught'): 72,
#   ('i', 'chose'): 12,
#   ('i', 'confessed'): 6,
#   ('i', 'could'): 795,
#   ('i', 'cry'): 6,
#   ('i', 'disagreed'): 3,
#   ('i', 'drank'): 55,
#   ('i', 'dug'): 4,
#   ('i', 'forgot'): 347,
#   ('i', 'grow'): 3,
#   ('i', 'hated'): 11,
#   ('i', 'heard'): 492,
#   ('i', 'hesitated'): 3,
#   ('i', 'hired'): 6,
#   ('i', 'live'): 129,
#   ('i', 'loved'): 36,
#   ('i', 'messed'): 1,
#   ('i', 'might'): 63,
#   ('i', 'missed'): 92,
#   ('i', 'needed'): 86,
#   ('i', 'never'): 666,
#   ('i', 'often'): 189,
#   ('i', 'oppose'): 1,
#   ('i', 'overslept'): 9,
#   ('i', 'pay'): 7,
#   ('i', 'play'): 63,
#   ('i', 'protested'): 4,
#   ('i', 'read'): 141,
#   ('i', 'recovered'): 3,
#   ('i', 'regret'): 83,
#   ('i', 'saved'): 15,
#   ('i', 'sell'): 12,
#   ('i', 'smell'): 12,
#   ('i', 'snickered'): 2,
#   ('i', 'stammered'): 2,
#   ('i', 'struggled'): 5,
#   ('i', 'succeeded'): 5,
#   ('i', 'surrender'): 2,
#   ('i', 'talk'): 19,
#   ('i', 'thank'): 20,
#   ('i', 'trust'): 29,
#   ('i', 'washed'): 25,
#   ('i', 'went'): 447,
#   ('i', 'whispered'): 1,
#   ('ignore', 'that'): 2,
#   ('ignore', 'them'): 2,
#   ('is', 'she'): 32,
#   ('it', 'ca'): 21,
#   ('it', 'cost'): 51,
#   ('it', 'happened'): 88,
#   ('it', 'may'): 81,
#   ('it', 'saved'): 2,
#   ('it', 'suits'): 2,
#   ('it', "'d"): 19,
#   ('jump', 'across'): 1,
#   ('just', 'ask'): 7,
#   ('just', 'get'): 10,
#   ('just', 'say'): 15,
#   ('just', 'try'): 8,
#   ('keep', 'trying'): 1,
#   ('life', 'is'): 82,
#   ('look', 'around'): 16,
#   ('look', 'closer'): 1,
#   ('make', 'a'): 19,
#   ('many', 'thanks'): 5,
#   ('memorize', 'it'): 8,
#   ('money', 'talks'): 2,
#   ('my', 'dog'): 78,
#   ('need', 'a'): 2,
#   ...},
#  421765)

# %%
np.random.seed(args.seed)

dataset_stage3 = []
for phrase, datum_list in sorted(data_subset.items()):
    np.random.shuffle(datum_list)
    n_train = int(len(datum_list) * args.perc_train)
    n_val = int(len(datum_list) * args.perc_val)

    for datum in datum_list[:n_train]:
        datum['split'] = 'train'
        
    for datum in datum_list[n_train:n_train+n_val]:
        datum['split'] = 'val'
        
    for datum in datum_list[n_train+n_val:]:
        datum['split'] = 'test'
    
    dataset_stage3.extend(datum_list)    

print(dataset_stage3[0])
# Out:
# {'english_tokens': ['100', 'years', 'is', 'called', 'a', 'century', '.'], 'russian_tokens': ['100', 'лет', 'называются', 'веком', '.'], 'split': 'train'}

# %%
# here we pop and assign into the dictionary, thus modifying in place
for datum in dataset_stage3:
    datum['source_language'] = " ".join(datum.pop('english_tokens'))
    datum['target_language'] = " ".join(datum.pop('russian_tokens'))

# %%
nmt_df = pd.DataFrame(dataset_stage3)

# %%
nmt_df.head()
# Out:
#    split                           source_language  \
# 0  train           100 years is called a century .
# 1   test           100 years is called a century .
# 2  train       2013 is a year i 'll never forget .
# 3   test  2013 is a year that i 'll never forget .
# 4   test                  2539 is a prime number .
#
#                                      target_language
# 0                         100 лет называются веком .
# 1                           сто лет называют веком .
# 2  две тысячи тринадцатый - год , который я никог...
# 3  две тысячи тринадцатый - год , который я никог...
# 4                             2539 — простое число .

# %%
nmt_df.to_csv(args.output_data_path)
